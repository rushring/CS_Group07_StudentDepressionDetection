# %%
import joblib

meta = joblib.load("/workspaces/CS_Group07_StudentDepressionDetection/notebooks/meta_model/final_meta_model.joblib")   # update path

print("Meta-model columns in correct order:")
print(list(meta.feature_names_in_))
# Out:
# Meta-model columns in correct order:
# ['DecisionTree', 'RandomForest', 'SVM', 'GradientBoosting', 'LogisticRegression', 'DecisionTree_abs', 'RandomForest_abs', 'SVM_abs', 'GradientBoosting_abs', 'LogisticRegression_abs', 'entropy', 'mean_proba', 'std_proba']
