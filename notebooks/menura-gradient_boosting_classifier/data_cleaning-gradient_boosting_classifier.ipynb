# %% [markdown]
# # Data Cleaning - Gradient Boosting Classifier Model

# %%
import pandas as pd

df = pd.read_csv("/workspaces/CS_Group07_StudentDepressionDetection/Data/Student Depression Dataset.csv")

# %% [markdown]
# ## Drop missing values (Null)

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# ## Drop Duplicates

# %%
print("Duplicate rows:", df.duplicated().sum())
df = df.drop_duplicates() #No need
# Out:
# Duplicate rows: 0

# %% [markdown]
# ## Clean Column Names

# %% [markdown]
# Removes spaces and question marks in column names

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_").str.replace("?", "")
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic_Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work_Pressure  CGPA  Study_Satisfaction  Job_Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep_Duration Dietary_Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %% [markdown]
# ## Drop Unwanted Data

# %% [markdown]
# Keep only the student's data

# %%
df = df[df['Profession'] == 'Student']

# %% [markdown]
# ## Drop Unwanted Columns

# %%
cols_to_drop = ['id', 'Work_Pressure', 'Job_Satisfaction', 'City', 'Profession']
df.drop(columns=[col for col in cols_to_drop if col in df.columns], inplace=True)
df.head()
# Out:
#    Gender   Age  Academic_Pressure  CGPA  Study_Satisfaction  \
# 0    Male  33.0                5.0  8.97                 2.0
# 1  Female  24.0                2.0  5.90                 5.0
# 2    Male  31.0                3.0  7.03                 5.0
# 3  Female  28.0                3.0  5.59                 2.0
# 4  Female  25.0                4.0  8.13                 3.0
#
#       Sleep_Duration Dietary_Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# 3          7-8 hours       Moderate      BCA
# 4          5-6 hours       Moderate   M.Tech
#
#   Have_you_ever_had_suicidal_thoughts_  Work/Study_Hours  Financial_Stress  \
# 0                                  Yes               3.0               1.0
# 1                                   No               3.0               2.0
# 2                                   No               9.0               1.0
# ...

# %% [markdown]
# ## Rename Columns

# %%
df.rename(columns={'Have_you_ever_had_suicidal_thoughts_': 'Suicidal Thoughts'}, inplace=True)
df.rename(columns={'Family_History_of_Mental_Illness': 'Mental Illness History'}, inplace=True)
df.rename(columns={'Work/Study_Hours': 'Study_Hours'}, inplace=True)
df.head()
# Out:
#    Gender   Age  Academic_Pressure  CGPA  Study_Satisfaction  \
# 0    Male  33.0                5.0  8.97                 2.0
# 1  Female  24.0                2.0  5.90                 5.0
# 2    Male  31.0                3.0  7.03                 5.0
# 3  Female  28.0                3.0  5.59                 2.0
# 4  Female  25.0                4.0  8.13                 3.0
#
#       Sleep_Duration Dietary_Habits   Degree Suicidal Thoughts  Study_Hours  \
# 0          5-6 hours        Healthy  B.Pharm               Yes          3.0
# 1          5-6 hours       Moderate      BSc                No          3.0
# 2  Less than 5 hours        Healthy       BA                No          9.0
# 3          7-8 hours       Moderate      BCA               Yes          4.0
# 4          5-6 hours       Moderate   M.Tech               Yes          1.0
#
#    Financial_Stress Mental Illness History  Depression
# 0               1.0                     No           1
# ...

# %% [markdown]
# ## Save cleaned Data set

# %%
df.to_csv("cleaned_student_depression(GBC-model).csv", index=False)
